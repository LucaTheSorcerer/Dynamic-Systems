# %% [markdown]
# ## Aufgabe 1

# %%
12 + 4 - 5
# Out:
# 11

# %%
2 ^ 10
# Out:
# 1024

# %%
sin(pi/2)
# Out:
# 1

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %%
14 + 2 * (5-3)
# Out:
# 18

# %% [markdown]
# ## Aufgabe 2

# %%
x = var('x')

p = x ^ 4 - 3/2 * x ^ 3 - x + 3/2 == 0

# %%
solve(p, x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
x1 = var('x')


p1 = (sqrt(x1 ^ 2 + 2 * x1) == 3)

# %%
solve(p1, x1)
# Out:
# [x == -sqrt(10) - 1, x == sqrt(10) - 1]

# %%
p2
# Out:
# sqrt(x^2 + 2*x) == 3

# %%
x = var('x')

solve(x^2 + 3*x + 2, x)
# Out:
# [x == -2, x == -1]

# %%
x = var('x')
y = var('y')

eq1 = 2 * x + y == 3
eq2 = x + 3 * y == -1

# %%
solve([eq1, eq2], x, y)
# Out:
# [[x == 2, y == -1]]

# %%
x = var('x')
y = var('y')

eq1 = 2 * x + x * y + 2 * y == 59
eq2 = 3 * x - 2 * x * y + 3 * y == -34

# %%
solve([eq1, eq2], x, y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %% [markdown]
# ## Aufgabe 3

# %%
limit((sin(x)/x), x = 0)
# Out:
# 1

# %%
limit((cos(x) + 1/ x - pi), x = pi)
# Out:
# -pi + 1/pi - 1

# %%
limit((x^3 + 3 * x ^ 2 - 5)/(2 * x ^ 3 - 7 * x), x = infinity)
# Out:
# 1/2

# %% [markdown]
# ## Aufgabe 4

# %%
x = var('x')
f(x) = 3 * x ^ 3 + 2 * x ^ 2 - 5
solve(derivative(f(x)), x)
# Out:
# [x == (-4/9), x == 0]

# %%
x = var('x')
f(x) = sqrt(1 + x ^ 4)
solve(derivative(f(x)), x)
# Out:
# [x == 0]

# %%
x = var('x')
f(x) = e ^ pi * sin(x) * cos(x)
solve(derivative(f(x)), x)
# Out:
# [sin(x) == -cos(x), sin(x) == cos(x)]

# %% [markdown]
# ## Aufgabe 5

# %%
integral((3 * x ^ 3 + 2 * x ^ 2 - 5), x, 0, 1)
# Out:
# -43/12

# %%
integral((1/x ^ 2), x, 1, infinity)
# Out:
# 1

# %%
integral((e ^ (-x ^ 2)), x, -infinity, infinity)
# Out:
# sqrt(pi)

# %% [markdown]
# ## Aufgabe 6

# %%
f(x) = e ^ (-x) - 1
plot(f(x), -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
L = [[(200 * e ^ (r * x))/(2 * (e ^ (r * x) - 1 + 100))] for x in range(200)]
plot(L, 0.5, -0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [72], line 1
# ----> 1 L = [[(Integer(200) * e ** (r * x))/(Integer(2) * (e ** (r * x) - Integer(1) + Integer(100)))] for x in range(Integer(200))]
#       2 plot(L, RealNumber('0.5'), -RealNumber('0.5'))
#
# Cell In [72], line 1, in <listcomp>(.0)
# ----> 1 L = [[(Integer(200) * e ** (r * x))/(Integer(2) * (e ** (r * x) - Integer(1) + Integer(100)))] for x in range(Integer(200))]
#       2 plot(L, RealNumber('0.5'), -RealNumber('0.5'))
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/misc/lazy_import.pyx:653, in sage.misc.lazy_import.LazyImport.__mul__ (build/cythonized/sage/misc/lazy_import.c:6065)()
#     651         20
#     652     """
# --> 653     return obj(left) * obj(right)
#     654
#     655 def __matmul__(left, right):
#
# ...

# %%
f(x) = x * sin(1/x)
plot(f(x), -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## Aufgabe 7

# %%
t =var('t')
x(t)= (1 - cos(t))*cos(t)
y(t)= (1 - cos(t))*sin(t)
parametric_plot((x(t), y(t)), (t, 0, pi*2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t =var('t')
x(t)= sin(3 * t)* cos(t)
y(t)= sin(3 * t) * sin(t)
parametric_plot((x(t), y(t)), (t, 0, pi*2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t =var('t')
x(t)= t - sin(t)
y(t)= 1 - cos(t)
parametric_plot((x(t), y(t)), (t, 0, pi*6))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t =var('t')
x(t)= cos(t) + (cos(7 * t) / 2) + (sin(17 * 7) / 3)
y(t)= sin(t) + (sin(7 * t) / 2) + (cos(17 * 7) / 3)
parametric_plot((x(t), y(t)), (t, 0, pi*2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## Aufgabe 8

# %%
f(t,s) = 1 - ((s * cos(4 * t) * cos(t))/(sqrt(1 - (s ^ 2) * (cos(4 * t) ^ 2) * (sin(t) ^ 2))))

# %%
t =var('t')
x(t)= t - (pi/2)
y(t)= sin(t) + (sin(7 * t) / 2) + (cos(17 * 7) / 3)
parametric_plot((x(t), y(t)), (t, 0, pi*2))

# %% [markdown]
# ## Aufgabe 9

# %%
f(x,y) = x^2+y^2 - 2 * x - 4 * y + 4

implicit_plot(f, (-3,3), (-3,3), fill=True, plot_points=500)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f(x,y) = x^2 - (2 * x * y) - (y ^ 2) == 0

implicit_plot(f, (-3,3), (-3,3), fill=True, plot_points=500)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f(x,y) = (6 * x^2) - (4 * y * x) + 9 * y ^ 2 - 4 * x - 32 * y - 6 == 0
implicit_plot(f, (-1,1), (-1,1), fill=True, plot_points=500)
# Out:
# Graphics object consisting of 2 graphics primitives
