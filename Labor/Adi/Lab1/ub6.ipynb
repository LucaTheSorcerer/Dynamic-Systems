# %%
x = var('x')
f(x) = (e^(-x) - 1)
plot(f(x), -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
r = 0.5
r = -0.5
f(x) = (200 * e^(r*x))/(2*(e^(r*x) - 1) + 100)
plot(f(x), 0, 50)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
f(x) = (x * sin(1/x))
plot(f(x), -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive
