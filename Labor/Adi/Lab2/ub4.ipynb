# %%
x = var('x')
y = function('y')(x)
eq = diff(y,x) - (1/2)*y == cos(x)
sol = desolve(eq,y)
_C = var('_C')
sol1 = sol.substitute(_C == 1)
plot(sol1,x,-1,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,a = var('x,a')
y = function('y')(x)
eq = diff(y,x) - (1/2)*y == cos(x)
desolve(eq,y,ics=[0,a])
# Out:
# 1/5*(5*a + 2)*e^(1/2*x) - 2/5*cos(x) + 4/5*sin(x)
