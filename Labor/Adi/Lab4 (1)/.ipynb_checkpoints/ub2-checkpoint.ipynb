# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]

# %%
sol=desolve_system(syst, vars,in_cond)
sol
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,1,5,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-4,4,color='red')
g2=plot(sol_y(t),t,1,5,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x-y+t-1
deq2=diff(y,t)==-2*x+y+1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]

# %%
sol=desolve_system(syst, vars,in_cond)
sol
# Out:
# [x(t) == -3*(sqrt(2)*sinh(sqrt(2)*t) - cosh(sqrt(2)*t))*e^t + t - 3,
#  y(t) == -3*(sqrt(2)*sinh(sqrt(2)*t) - 2*cosh(sqrt(2)*t))*e^t + 2*t - 5]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -3*(sqrt(2)*sinh(sqrt(2)*t) - cosh(sqrt(2)*t))*e^t + t - 3

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -3*(sqrt(2)*sinh(sqrt(2)*t) - 2*cosh(sqrt(2)*t))*e^t + 2*t - 5

# %%
plot(sol_x(t),t,1,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,1,4,color='red')
g2=plot(sol_y(t),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+2*y+e^-t
deq2=diff(y,t)==-2*x+y+1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]

# %%
sol=desolve_system(syst, vars,in_cond)
sol
# Out:
# [x(t) == -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,1-4,4,color='red')
g2=plot(sol_y(t),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives
