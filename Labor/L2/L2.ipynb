# %%
var('x y C')
diff(y,x) - 2*x*y == 0
f(x) = e^(C)*e^(x^2)
show(f(x))
# Out:
# e^(x^2 + C)

# %%
p1 = plot(0, (x,-2,2), color='white', axes_labels=['x', 'y'], figsize=[6,4])
for C_val in [-1, 0, 1]:
    f(x) = C_val*e^(x^2)
    p1 += plot(f(x), (x,-2,2), color=hue(C_val))
show(p1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
diff(y,x) == y/x
# Out:
# 0 == y/x

# %%
var('x y C')
diff(y,x) = y/x
f(x) = C_val*e^(x^2/2)


p1 = plot(0, (x,-2,2), color='white', axes_labels=['x', 'y'], figsize=[6,4])
for C_val in [-1, 0, 1]:
    p1 += plot(f(x), (x,-2,2), color=hue(C_val))
show(p1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
diff(y,x) == 2*x*(1 + y^2)
# Out:
# 2*(x^2 + 1)*y == 2*(y^2 + 1)*x

# %%
dy/(1+y^2) == 2 * x dx
arctan(y) == x^2 + C
# Out:
#   Cell In [17], line 1
#     dy/(Integer(1)+y**Integer(2)) == Integer(2) * x dx
#                                                     ^
# SyntaxError: invalid syntax

# %%
x = var('x')

y = function('y')(x)

desolve(diff(y,x) + y - 1, y)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [28], line 5
#       1 x = var('x')
#       3 y = function('y')(x)
# ----> 5 desolve(diff(y,x) + y - Integer(1), y)
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/calculus/desolvers.py:598, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     596             raise NotImplementedError("Maxima was unable to solve this ODE.")
#     597     else:
# --> 598         raise NotImplementedError("Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.")
#     600 if show_method:
#     601     maxima_method=P("method")
#
# NotImplementedError: Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.

# %%
#1
x=var('x')
y=function('y')(x)
eqd=diff(y,x) == 2*x*y
sol=desolve(eqd, y, contrib_ode=True)

_C=var('_C')
sol.substitute(_C==1)
sol1 = sol.substitute(_C==1)

g = plot(sol1, x, -2, 2)
for i in [10..100]:
    sol1=sol.substitute(_C==i)
    g=g+plot(sol1, x, -2, 2)

show(g)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [30], line 5
#       3 y=function('y')(x)
#       4 eqd=diff(y,x) == Integer(2)*x*y
# ----> 5 sol=desolve(eqd, y, contrib_ode=True)
#       7 _C=var('_C')
#       8 sol.substitute(_C==Integer(1))
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/calculus/desolvers.py:596, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     594     soln = P(cmd)
#     595     if str(soln).strip() == 'false':
# --> 596         raise NotImplementedError("Maxima was unable to solve this ODE.")
#     597 else:
#     598     raise NotImplementedError("Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.")
#
# NotImplementedError: Maxima was unable to solve this ODE.

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x) == y/x
sol=desolve(eqd, y, contrib_ode=True)

_C=var('_C')
sol.substitute(_C==1)
sol1 = sol.substitute(_C==1)

g = plot(sol1, x, -2, 2)
for i in [10..100]:
    sol1=sol.substitute(_C==i)
    g=g+plot(sol1, x, -2, 2)

show(g)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [32], line 4
#       2 y=function('y')(x)
#       3 eqd=diff(y,x) == y/x
# ----> 4 sol=desolve(eqd, y, contrib_ode=True)
#       6 _C=var('_C')
#       7 sol.substitute(_C==Integer(1))
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/calculus/desolvers.py:596, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     594     soln = P(cmd)
#     595     if str(soln).strip() == 'false':
# --> 596         raise NotImplementedError("Maxima was unable to solve this ODE.")
#     597 else:
#     598     raise NotImplementedError("Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.")
#
# NotImplementedError: Maxima was unable to solve this ODE.

# %% [markdown]
# ## Aufgabe 2

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x) == 2*x*(1+y^2)
sol=desolve(eqd, y)
#sol
a = solve(sol, y)
#a

b(x,_C)=a[0].rhs()
plot(b(x,1), x, -3, 3, ymin=-5, ymax=5)

x=var('x')
y=function('y')(x)
eqd=diff(y,x) == -2*x*y^2/(x^2-1)
sol=desolve(eqd, y)
sol

a = solve(sol, y)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [33], line 4
#       2 y=function('y')(x)
#       3 eqd=diff(y,x) == Integer(2)*x*(Integer(1)+y**Integer(2))
# ----> 4 sol=desolve(eqd, y)
#       5 #sol
#       6 a = solve(sol, y)
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/calculus/desolvers.py:598, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     596             raise NotImplementedError("Maxima was unable to solve this ODE.")
#     597     else:
# --> 598         raise NotImplementedError("Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.")
#     600 if show_method:
#     601     maxima_method=P("method")
#
# NotImplementedError: Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.

# %%
b(x, _C) = a[0].rhs()
plot(b(x, 1), x, 1, 3, ymin=-2, ymax=2)

x=var('x')
y=function('y')(x)
eqd=diff(y,x) == 1/cos(x) - y*tan(x)
sol=desolve(eqd, y)
sol

_C=var('_C')
sol.substitute(_C==1)
sol1 = sol.substitute(_C==1)

g = plot(sol1, x, -2, 2)
for i in [10..100]:
    sol1=sol.substitute(_C==i)
    g=g+plot(sol1, x, -4, 4)

show(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 __tmp__=var("x,_C"); b = symbolic_expression(a[Integer(0)].rhs()).function(x,_C)
#       2 plot(b(x, Integer(1)), x, Integer(1), Integer(3), ymin=-Integer(2), ymax=Integer(2))
#       4 x=var('x')
#
# NameError: name 'a' is not defined

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x) == x^3-2/x*y
desolve(eqd, y)

sol = desolve(eqd, y)
_C=var('_C')
sol.substitute(_C==1)
sol1=sol.substitute(_C==1)
plot(sol1, x, 1, 4)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [35], line 4
#       2 y=function('y')(x)
#       3 eqd=diff(y,x) == x**Integer(3)-Integer(2)/x*y
# ----> 4 desolve(eqd, y)
#       6 sol = desolve(eqd, y)
#       7 _C=var('_C')
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/calculus/desolvers.py:598, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     596             raise NotImplementedError("Maxima was unable to solve this ODE.")
#     597     else:
# --> 598         raise NotImplementedError("Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.")
#     600 if show_method:
#     601     maxima_method=P("method")
#
# NotImplementedError: Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x) == 3*x-1/x*y
desolve(eqd, y)

sol = desolve(eqd, y)
_C=var('_C')
sol.substitute(_C==1)
sol1=sol.substitute(_C==1)
plot(sol1, x, 1, 4)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [36], line 4
#       2 y=function('y')(x)
#       3 eqd=diff(y,x) == Integer(3)*x-Integer(1)/x*y
# ----> 4 desolve(eqd, y)
#       6 sol = desolve(eqd, y)
#       7 _C=var('_C')
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/calculus/desolvers.py:598, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     596             raise NotImplementedError("Maxima was unable to solve this ODE.")
#     597     else:
# --> 598         raise NotImplementedError("Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.")
#     600 if show_method:
#     601     maxima_method=P("method")
#
# NotImplementedError: Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y, x) == 1+y^2
desolve(eqd,y,ics=[0, 1])

a = solve(sol, y)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [37], line 4
#       2 y=function('y')(x)
#       3 eqd=diff(y, x) == Integer(1)+y**Integer(2)
# ----> 4 desolve(eqd,y,ics=[Integer(0), Integer(1)])
#       6 a = solve(sol, y)
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/calculus/desolvers.py:598, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     596             raise NotImplementedError("Maxima was unable to solve this ODE.")
#     597     else:
# --> 598         raise NotImplementedError("Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.")
#     600 if show_method:
#     601     maxima_method=P("method")
#
# NotImplementedError: Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.

# %%
b(x, _C) = a[0].rhs()
plot(b(x, 1), x, 1, 3, ymin=-2, ymax=2)

x=var('x')
y=function('y')(x)
eqd=diff(y, x) == -x^2 + 2*y
desolve(eqd,y,ics=[0, 1/4])

a = solve(sol, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 __tmp__=var("x,_C"); b = symbolic_expression(a[Integer(0)].rhs()).function(x,_C)
#       2 plot(b(x, Integer(1)), x, Integer(1), Integer(3), ymin=-Integer(2), ymax=Integer(2))
#       4 x=var('x')
#
# NameError: name 'a' is not defined

# %%
b(x, _C) = a[0].rhs()
plot(b(x, 1), x, 1, 3, ymin=-2, ymax=2)

x=var('x')
y=function('y')(x)
eqd=diff(y, x) == 1/cos(x) - (y*tan(x))
desolve(eqd,y,ics=[0, 1/4])

a = solve(sol, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 __tmp__=var("x,_C"); b = symbolic_expression(a[Integer(0)].rhs()).function(x,_C)
#       2 plot(b(x, Integer(1)), x, Integer(1), Integer(3), ymin=-Integer(2), ymax=Integer(2))
#       4 x=var('x')
#
# NameError: name 'a' is not defined

# %%
b(x, _C) = a[0].rhs()
plot(b(x, 1), x, 1, 3, ymin=-2, ymax=2)

x,k=var('x,k')
k=var('k')
y=function('y')(x)
eqd=diff(y, x) == x^3 - k/x*y
sol=desolve(eqd, [y, x])

_C=var('_C')
sol1=sol.substitute(_C=1,k=1)
plot(sol1, x, 1, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 __tmp__=var("x,_C"); b = symbolic_expression(a[Integer(0)].rhs()).function(x,_C)
#       2 plot(b(x, Integer(1)), x, Integer(1), Integer(3), ymin=-Integer(2), ymax=Integer(2))
#       4 x,k=var('x,k')
#
# NameError: name 'a' is not defined

# %%
y = function('y')(x)

de = diff(y,x) + y -2

h = desolve(de, y)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [42], line 5
#       1 y = function('y')(x)
#       3 de = diff(y,x) + y -Integer(2)
# ----> 5 h = desolve(de, y)
#
# File /private/var/tmp/sage-9.8-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/calculus/desolvers.py:598, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     596             raise NotImplementedError("Maxima was unable to solve this ODE.")
#     597     else:
# --> 598         raise NotImplementedError("Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.")
#     600 if show_method:
#     601     maxima_method=P("method")
#
# NotImplementedError: Maxima was unable to solve this ODE. Consider to set option contrib_ode to True.
