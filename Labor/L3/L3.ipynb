# %% [markdown]
# # Laboratory 3

# %% [markdown]
# ## Exercise 1

# %%
#y''+ y = sinx + cosx
# 1/a:
x=var('x')
y=function('y')(x)
eqd=diff(y, x, 2) + y == sin(x) + cos(x)
sol=desolve(eqd, y)
sol
# Out:
# _K2*cos(x) - 1/2*(x - 1)*cos(x) + _K1*sin(x) + 1/2*x*sin(x)

# %%
_K1, _K2=var('_K1', '_K2')
soll1 = sol.substitute(_K1==0, _K2==0)
soll2 = sol.substitute(_K1==0, _K2==1)
soll3 = sol.substitute(_K1==0, _K2==-1)

plot([soll1, soll2, soll3], x, -2, 2)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
reset()

# %%
#1/b:
#y'' - y = e^2x
x=var('x')
y=function('y')(x)
eqd=diff(y, x, 2) - y == e ^ (2 * x)
sol=desolve(eqd, y)
sol
# Out:
# _K2*e^(-x) + _K1*e^x + 1/3*e^(2*x)

# %%
_K1, _K2=var('_K1', '_K2')
soll = sol.substitute(_K1==1, _K2==4)
plot(soll, x, -8, 8)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#c)
#y'' + 4y = 1/cos2x

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y, x, 2) + 4*y == 1/(cos(2*x))
sol=desolve(eqd, y)
sol
# Out:
# _K2*cos(2*x) + 1/4*cos(2*x)*log(cos(2*x)) + _K1*sin(2*x) + 1/2*x*sin(2*x)

# %%
_K1, _K2=var('_K1', '_K2')
soll = sol.substitute(_K1==1, _K2==4)
plot(soll, x, -8, 8)
# Out:
# verbose 0 (3899: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 103 points.
# verbose 0 (3899: plot.py, generate_plot_points) Last error message: 'Unable to compute f(8.0)'
# Graphics object consisting of 5 graphics primitives

# %%
reset()

# %%
#d)
#y''- y' = 1/1 + e ^ x
x=var('x')
y=function('y')(x)
eqd=diff(y, x, 2) + diff(y, x) == 1 / (1+e^x)
sol=desolve(eqd, y)
sol
# Out:
# (x*e^x - (e^x + 1)*log(e^x + 1))*e^(-x) + _K2*e^(-x) + _K1

# %%
_K1, _K2=var('_K1', '_K2')
soll = sol.substitute(_K1==1, _K2==4)
plot(soll, x, -8, 8)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### a)  y'' - 5y' + 4y = 0 , y(0) = 5, y'(0) = 8;

# %%
x=var('x')
y=function('y')(x)
eqd = diff(y,x,2) - 5 * diff(y, x) + 4*y == 0
sol = desolve(eqd, y, ics=[0, 5, 8])
sol

plot(sol, x, -2, 2, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()

# %% [markdown]
# ## b) y'' - 4y' + 5y = 2 * x ^ 2 * e ^ x , y(0) = 2, y'(0) = 3

# %%
# 2/b:
x=var('x')
y=function('y')(x)
eqd = diff(y,x,2) - 4 * diff(y, x) + 5*y == 2*x^2*e^x
sol = desolve(eqd, y, ics=[0, 2, 3])
sol


plot(sol, x, -2, 2, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## c) y'' + 4y = 4 (sin 2x + cos 2x), y(pi) = y'(pi) = 2

# %%
x=var('x')
y=function('y')(x)
eqd = diff(y,x,2) + 4 * y == 4 * (sin(2*x) + cos(2*x))
sol = desolve(eqd, y, ics=[pi, 2, 3])
sol
# Out:
# 1/2*(2*pi + 3)*cos(2*x) - 1/2*(2*x - 1)*cos(2*x) - (pi - 2)*sin(2*x) + x*sin(2*x)

# %%
plot(sol, x, -2, 2, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()

# %% [markdown]
# # Exercise 3

# %% [markdown]
# ## y'' - y' - 2y = 0
# ## y(0) = a
# ## y(0) = 2

# %%
x, a=var('x', 'a')
y=function('y')(x)
eqd = diff(y,x,2) - diff(y, x) - 2*y == 0
sol = desolve(eqd, y, ics=[0, a, 2])
sol
# Out:
# 1/3*(a + 2)*e^(2*x) + 2/3*(a - 1)*e^(-x)

# %%
sol1 = sol.substitute(a=-2)
sol1
# Out:
# -2*e^(-x)
